# %% [markdown]
# # Initiation Python - Datasets

# %% [markdown]
# ## Langage interprété

# %% [markdown]
# Python est un langage interprété, ce qui signifie qu'on peut évaluer des expressions seules en exécutant (avec le bouton "Executer" ou CTRL + ENTER) la cellule concernée

# %% [markdown]
# Exécutez les cellules suivantes et observez les sorties :

# %%
 10*6+18
# Out:
# 78

# %%
a = "je pense donc je suis"

# %%
a
# Out:
# 'je pense donc je suis'

# %%
print(a)
# Out:
# je pense donc je suis

# %%
b = 40

# %%
b * 10 - 25
# Out:
# 375

# %%
liste=range(10)

# %%
liste[2:4]
# Out:
# range(2, 4)

# %%
liste[2:6:2]
# Out:
# range(2, 6, 2)

# %%
liste[10:4]
# Out:
# range(10, 4)

# %%
liste[::2]
# Out:
# range(0, 10, 2)

# %%
liste2=[x**2 for x in liste]

# %%
liste3=[x**2 for x in liste if x%2==0]

# %%
reponse=input("Gauche ou Droite ? ")
# Out:
# Gauche ou Droite ? droite

# %%
reponse
# Out:
# 'droite'

# %% [markdown]
# ## Challenges

# %% [markdown]
# Créer une liste nommée prix_de_58_maisons contenant des prix de 58 maisons entre 125000€ et 700000€

# %% [markdown]
# A l’aide de boucles et de tests répondez aux questions suivantes :
#
# Combien de maisons ont un prix supérieur ou égal à 300000€ ?
# Combien de maisons ont un prix compris entre 250000€ et 400000€ ?
# Combien de maisons ont un prix qui n’est pas supérieur à 600000€ ?
# Combien de maisons ont un prix inférieur à 150000€ ou supérieur à 650000€ ?

# %% [markdown]
# Créer 4 fonctions Python permettant de calculer :
# - Moyenne
# - Variance
# - Ecart-type
# - Médiane

# %% [markdown]
# ## Import fichier

# %% [markdown]
# > Import des fichiers et stockage de manière propre dans des dataframes  (3 fichiers : prima.txt, mar2012.csv, mar2012.dbf)
# > Notebook respectant pep8
# > Un titre de notebook
# > sommaire interactif
# > parties en titre
# > Retour au sommaire à chaque partie

# %%
prima_df = pd.read_csv('prima.txt', delimiter='\t')

print(prima_df.head())
# Out:
#    pregnant  glucose  diastolic  triceps  insulin   bmi  diabetes  age  test
# 0         6      148         72       35        0  33.6     0.627   50     1
# 1         1       85         66       29        0  26.6     0.351   31     0
# 2         8      183         64        0        0  23.3     0.672   32     1
# 3         1       89         66       23       94  28.1     0.167   21     0
# 4         0      137         40       35      168  43.1     2.288   33     1

# %%
mar2012_csv_df = pd.read_csv('mar2012.csv', encoding="latin-1", low_memory=False)
print(mar2012_csv_df.head())
# Out:
#                                                                                                              Année 2022
# ANAISH DEPNAISH INDNATH ETAMATH ANAISF DEPNAISF INDNATF ETAMATF AMAR MMAR JSEMAINE DEPMAR DEPDOM TUDOM TUCOM   NBENFCOM
# 1982   75       1       1       1984   99       2       1       2012 01   1        29     99     9     NaN            N
# 1956   69       2       4       1969   99       2       4       2012 01   3        75     99     9     NaN            N
# 1982   99       2       1       1992   99       1       1       2012 01   5        34     99     9     NaN            N
# 1985   99       2       1       1987   84       1       1       2012 01   4        13     99     9     NaN            N

# %%
# !pip install dbfread
from dbfread import DBF
import pandas as pd

mar2012_dbf = DBF('mar2012.dbf')
mar2012_dbf_df = pd.DataFrame(iter(mar2012_dbf))
mar2012_dbf_df.head(10)
# Out:
# Requirement already satisfied: dbfread in /home/djesson/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (2.0.7)
#   ANAISH DEPNAISH INDNATH ETAMATH ANAISF DEPNAISF INDNATF ETAMATF  AMAR MMAR  \
# 0   1982       75       1       1   1984       99       2       1  2012   01
# 1   1956       69       2       4   1969       99       2       4  2012   01
# 2   1982       99       2       1   1992       99       1       1  2012   01
# 3   1985       99       2       1   1987       84       1       1  2012   01
# 4   1968       99       2       1   1963       99       2       1  2012   01
# 5   1978       99       2       1   1984       99       2       4  2012   01
# 6   1979       99       2       1   1979       03       1       1  2012   01
# 7   1976       50       1       1   1974       74       1       1  2012   01
# 8   1979       75       1       1   1979       75       1       1  2012   01
# 9   1976       99       2       1   1978       59       1       1  2012   01
#
#   JSEMAINE DEPMAR DEPDOM TUDOM TUCOM NBENFCOM
# 0        1     29     99     9              N
# 1        3     75     99     9              N
# 2        5     34     99     9              N
# 3        4     13     99     9              N
# 4        6     26     99     9              N
# 5        6     60     99     9              N
# 6        6     66     99     9              N
# 7        6     69     99     9              N
# 8        6     92     99     9              N
# 9        6     59     99     9              N

# %% [markdown]
# ## Explorer une base de données

# %% [markdown]
# Nous allons étudier un jeu de données très simple et très connue : IRIS. Ce dataset contient les informations de 3 variétés de fleurs sur leurs longueurs et largeurs, de sépal et de pétales.
# Ce premier exercice vous permettra de manipuler les données et de bien appréhender le langage Python.
# Comme pour tous les langages, vous trouverez énormément de documentations et d'aide en ligne, n'hésitez pas à chercher et tester des choses.

# %% [markdown]
# 1. Import des données

# %%
# !pip install pydataset
# Out:
# Collecting pydataset
#   Downloading pydataset-0.2.0.tar.gz (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 9.3 MB/s eta 0:00:00:00:010:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /home/djesson/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pydataset) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/djesson/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas->pydataset) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/djesson/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas->pydataset) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/djesson/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas->pydataset) (1.23.4)
# Requirement already satisfied: six>=1.5 in /home/djesson/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->pydataset) (1.16.0)
# Building wheels for collected packages: pydataset
#   Building wheel for pydataset (setup.py) ... done
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939416 sha256=37fb1b8debf898fb750077402c3ef44c7738a40f3163adadb5b93945d8077edf
#   Stored in directory: /home/djesson/.cache/pip/wheels/2b/83/5c/073c3755e8b7704e4677557b2055e61026c1a2342149214c13
# Successfully built pydataset
# Installing collected packages: pydataset
# Successfully installed pydataset-0.2.0

# %%
from pydataset import data
iris = data("iris")

# %% [markdown]
# 2. Afficher les données

# %%
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# 13            4.8          3.0           1.4          0.1      setosa
# 14            4.3          3.0           1.1          0.1      setosa
# 15            5.8          4.0           1.2          0.2      setosa
# 16            5.7          4.4           1.5          0.4      setosa
# 17            5.4          3.9           1.3          0.4      setosa
# 18            5.1          3.5           1.4          0.3      setosa
# 19            5.7          3.8           1.7          0.3      setosa
# 20            5.1          3.8           1.5          0.3      setosa
# 21            5.4          3.4           1.7          0.2      setosa
# 22            5.1          3.7           1.5          0.4      setosa
# 23            4.6          3.6           1.0          0.2      setosa
# 24            5.1          3.3           1.7          0.5      setosa
# 25            4.8          3.4           1.9          0.2      setosa
# 26            5.0          3.0           1.6          0.2      setosa
# 27            5.0          3.4           1.6          0.4      setosa
# 28            5.2          3.5           1.5          0.2      setosa
# 29            5.2          3.4           1.4          0.2      setosa
# 30            4.7          3.2           1.6          0.2      setosa
# 31            4.8          3.1           1.6          0.2      setosa
# 32            5.4          3.4           1.5          0.4      setosa
# 33            5.2          4.1           1.5          0.1      setosa
# 34            5.5          4.2           1.4          0.2      setosa
# 35            4.9          3.1           1.5          0.2      setosa
# 36            5.0          3.2           1.2          0.2      setosa
# 37            5.5          3.5           1.3          0.2      setosa
# 38            4.9          3.6           1.4          0.1      setosa
# 39            4.4          3.0           1.3          0.2      setosa
# 40            5.1          3.4           1.5          0.2      setosa
# 41            5.0          3.5           1.3          0.3      setosa
# 42            4.5          2.3           1.3          0.3      setosa
# 43            4.4          3.2           1.3          0.2      setosa
# 44            5.0          3.5           1.6          0.6      setosa
# 45            5.1          3.8           1.9          0.4      setosa
# 46            4.8          3.0           1.4          0.3      setosa
# 47            5.1          3.8           1.6          0.2      setosa
# 48            4.6          3.2           1.4          0.2      setosa
# 49            5.3          3.7           1.5          0.2      setosa
# 50            5.0          3.3           1.4          0.2      setosa
# 51            7.0          3.2           4.7          1.4  versicolor
# 52            6.4          3.2           4.5          1.5  versicolor
# 53            6.9          3.1           4.9          1.5  versicolor
# 54            5.5          2.3           4.0          1.3  versicolor
# 55            6.5          2.8           4.6          1.5  versicolor
# 56            5.7          2.8           4.5          1.3  versicolor
# 57            6.3          3.3           4.7          1.6  versicolor
# 58            4.9          2.4           3.3          1.0  versicolor
# 59            6.6          2.9           4.6          1.3  versicolor
# 60            5.2          2.7           3.9          1.4  versicolor
# 61            5.0          2.0           3.5          1.0  versicolor
# 62            5.9          3.0           4.2          1.5  versicolor
# 63            6.0          2.2           4.0          1.0  versicolor
# 64            6.1          2.9           4.7          1.4  versicolor
# 65            5.6          2.9           3.6          1.3  versicolor
# 66            6.7          3.1           4.4          1.4  versicolor
# 67            5.6          3.0           4.5          1.5  versicolor
# 68            5.8          2.7           4.1          1.0  versicolor
# 69            6.2          2.2           4.5          1.5  versicolor
# 70            5.6          2.5           3.9          1.1  versicolor
# 71            5.9          3.2           4.8          1.8  versicolor
# 72            6.1          2.8           4.0          1.3  versicolor
# 73            6.3          2.5           4.9          1.5  versicolor
# 74            6.1          2.8           4.7          1.2  versicolor
# 75            6.4          2.9           4.3          1.3  versicolor
# 76            6.6          3.0           4.4          1.4  versicolor
# 77            6.8          2.8           4.8          1.4  versicolor
# 78            6.7          3.0           5.0          1.7  versicolor
# 79            6.0          2.9           4.5          1.5  versicolor
# 80            5.7          2.6           3.5          1.0  versicolor
# 81            5.5          2.4           3.8          1.1  versicolor
# 82            5.5          2.4           3.7          1.0  versicolor
# 83            5.8          2.7           3.9          1.2  versicolor
# 84            6.0          2.7           5.1          1.6  versicolor
# 85            5.4          3.0           4.5          1.5  versicolor
# 86            6.0          3.4           4.5          1.6  versicolor
# 87            6.7          3.1           4.7          1.5  versicolor
# 88            6.3          2.3           4.4          1.3  versicolor
# 89            5.6          3.0           4.1          1.3  versicolor
# 90            5.5          2.5           4.0          1.3  versicolor
# 91            5.5          2.6           4.4          1.2  versicolor
# 92            6.1          3.0           4.6          1.4  versicolor
# 93            5.8          2.6           4.0          1.2  versicolor
# 94            5.0          2.3           3.3          1.0  versicolor
# 95            5.6          2.7           4.2          1.3  versicolor
# 96            5.7          3.0           4.2          1.2  versicolor
# 97            5.7          2.9           4.2          1.3  versicolor
# 98            6.2          2.9           4.3          1.3  versicolor
# 99            5.1          2.5           3.0          1.1  versicolor
# 100           5.7          2.8           4.1          1.3  versicolor
# 101           6.3          3.3           6.0          2.5   virginica
# 102           5.8          2.7           5.1          1.9   virginica
# 103           7.1          3.0           5.9          2.1   virginica
# 104           6.3          2.9           5.6          1.8   virginica
# 105           6.5          3.0           5.8          2.2   virginica
# 106           7.6          3.0           6.6          2.1   virginica
# 107           4.9          2.5           4.5          1.7   virginica
# 108           7.3          2.9           6.3          1.8   virginica
# 109           6.7          2.5           5.8          1.8   virginica
# 110           7.2          3.6           6.1          2.5   virginica
# 111           6.5          3.2           5.1          2.0   virginica
# 112           6.4          2.7           5.3          1.9   virginica
# 113           6.8          3.0           5.5          2.1   virginica
# 114           5.7          2.5           5.0          2.0   virginica
# 115           5.8          2.8           5.1          2.4   virginica
# 116           6.4          3.2           5.3          2.3   virginica
# 117           6.5          3.0           5.5          1.8   virginica
# 118           7.7          3.8           6.7          2.2   virginica
# 119           7.7          2.6           6.9          2.3   virginica
# 120           6.0          2.2           5.0          1.5   virginica
# 121           6.9          3.2           5.7          2.3   virginica
# 122           5.6          2.8           4.9          2.0   virginica
# 123           7.7          2.8           6.7          2.0   virginica
# 124           6.3          2.7           4.9          1.8   virginica
# 125           6.7          3.3           5.7          2.1   virginica
# 126           7.2          3.2           6.0          1.8   virginica
# 127           6.2          2.8           4.8          1.8   virginica
# 128           6.1          3.0           4.9          1.8   virginica
# 129           6.4          2.8           5.6          2.1   virginica
# 130           7.2          3.0           5.8          1.6   virginica
# 131           7.4          2.8           6.1          1.9   virginica
# 132           7.9          3.8           6.4          2.0   virginica
# 133           6.4          2.8           5.6          2.2   virginica
# 134           6.3          2.8           5.1          1.5   virginica
# 135           6.1          2.6           5.6          1.4   virginica
# 136           7.7          3.0           6.1          2.3   virginica
# 137           6.3          3.4           5.6          2.4   virginica
# 138           6.4          3.1           5.5          1.8   virginica
# 139           6.0          3.0           4.8          1.8   virginica
# 140           6.9          3.1           5.4          2.1   virginica
# 141           6.7          3.1           5.6          2.4   virginica
# 142           6.9          3.1           5.1          2.3   virginica
# 143           5.8          2.7           5.1          1.9   virginica
# 144           6.8          3.2           5.9          2.3   virginica
# 145           6.7          3.3           5.7          2.5   virginica
# 146           6.7          3.0           5.2          2.3   virginica
# 147           6.3          2.5           5.0          1.9   virginica
# 148           6.5          3.0           5.2          2.0   virginica
# 149           6.2          3.4           5.4          2.3   virginica
# 150           5.9          3.0           5.1          1.8   virginica

# %% [markdown]
# Utiliser les fonctions head() et tail() pour afficher les 5 premières et 5 dernières lignes du dataset

# %%
from pydataset import data
iris = data("iris")
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
from pydataset import data
iris = data("iris")
iris.tail()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 146           6.7          3.0           5.2          2.3  virginica
# 147           6.3          2.5           5.0          1.9  virginica
# 148           6.5          3.0           5.2          2.0  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# 3. Quel est la taille du dataset ? Utiliser la fonction shape et interpréter le résultat

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# 4. Afficher toutes les colonnes du dataset

# %%
iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %% [markdown]
# 5. Sélectionner uniquement la colonnes Sepal.Length

# %%
iris[["Sepal.Length"]]
# Out:
#      Sepal.Length
# 1             5.1
# 2             4.9
# 3             4.7
# 4             4.6
# 5             5.0
# 6             5.4
# 7             4.6
# 8             5.0
# 9             4.4
# 10            4.9
# 11            5.4
# 12            4.8
# 13            4.8
# 14            4.3
# 15            5.8
# 16            5.7
# 17            5.4
# 18            5.1
# 19            5.7
# 20            5.1
# 21            5.4
# 22            5.1
# 23            4.6
# 24            5.1
# 25            4.8
# 26            5.0
# 27            5.0
# 28            5.2
# 29            5.2
# 30            4.7
# 31            4.8
# 32            5.4
# 33            5.2
# 34            5.5
# 35            4.9
# 36            5.0
# 37            5.5
# 38            4.9
# 39            4.4
# 40            5.1
# 41            5.0
# 42            4.5
# 43            4.4
# 44            5.0
# 45            5.1
# 46            4.8
# 47            5.1
# 48            4.6
# 49            5.3
# 50            5.0
# 51            7.0
# 52            6.4
# 53            6.9
# 54            5.5
# 55            6.5
# 56            5.7
# 57            6.3
# 58            4.9
# 59            6.6
# 60            5.2
# 61            5.0
# 62            5.9
# 63            6.0
# 64            6.1
# 65            5.6
# 66            6.7
# 67            5.6
# 68            5.8
# 69            6.2
# 70            5.6
# 71            5.9
# 72            6.1
# 73            6.3
# 74            6.1
# 75            6.4
# 76            6.6
# 77            6.8
# 78            6.7
# 79            6.0
# 80            5.7
# 81            5.5
# 82            5.5
# 83            5.8
# 84            6.0
# 85            5.4
# 86            6.0
# 87            6.7
# 88            6.3
# 89            5.6
# 90            5.5
# 91            5.5
# 92            6.1
# 93            5.8
# 94            5.0
# 95            5.6
# 96            5.7
# 97            5.7
# 98            6.2
# 99            5.1
# 100           5.7
# 101           6.3
# 102           5.8
# 103           7.1
# 104           6.3
# 105           6.5
# 106           7.6
# 107           4.9
# 108           7.3
# 109           6.7
# 110           7.2
# 111           6.5
# 112           6.4
# 113           6.8
# 114           5.7
# 115           5.8
# 116           6.4
# 117           6.5
# 118           7.7
# 119           7.7
# 120           6.0
# 121           6.9
# 122           5.6
# 123           7.7
# 124           6.3
# 125           6.7
# 126           7.2
# 127           6.2
# 128           6.1
# 129           6.4
# 130           7.2
# 131           7.4
# 132           7.9
# 133           6.4
# 134           6.3
# 135           6.1
# 136           7.7
# 137           6.3
# 138           6.4
# 139           6.0
# 140           6.9
# 141           6.7
# 142           6.9
# 143           5.8
# 144           6.8
# 145           6.7
# 146           6.7
# 147           6.3
# 148           6.5
# 149           6.2
# 150           5.9

# %% [markdown]
# 6. Regarder le nombre de fleurs par variétés que contient le dataset (utiliser la fonction value_count)

# %%
iris.Species.value_counts(normalize=True)
# Out:
# setosa        0.333333
# versicolor    0.333333
# virginica     0.333333
# Name: Species, dtype: float64

# %% [markdown]
# 7. Quelle est la largeur moyenne du sépal ?

# %%
moyenne_sepal_width = iris["Sepal.Width"].mean()

print("La largeur moyenne du sépale est:", moyenne_sepal_width)
# Out:
# La largeur moyenne du sépale est: 3.0573333333333337

# %% [markdown]
# 8. Quelle est la valeur maximale de longueur de pétale ?

# %%
iris["Petal.Width"].max()
# Out:
# 2.5

# %% [markdown]
# 9. Sélectionner uniquement les données pour lesquelles la longueur du pétal est >= 5.1 et stocker le résultat dans une nouvelle variable

# %%
# Sélection des données pour lesquelles la longueur du pétale est >= 5.1
petal_length_gt_5_1 = iris[iris["Petal.Length"] >= 5.1]

# Affichage des premières lignes pour vérification
petal_length_gt_5_1
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 84            6.0          2.7           5.1          1.6  versicolor
# 101           6.3          3.3           6.0          2.5   virginica
# 102           5.8          2.7           5.1          1.9   virginica
# 103           7.1          3.0           5.9          2.1   virginica
# 104           6.3          2.9           5.6          1.8   virginica
# 105           6.5          3.0           5.8          2.2   virginica
# 106           7.6          3.0           6.6          2.1   virginica
# 108           7.3          2.9           6.3          1.8   virginica
# 109           6.7          2.5           5.8          1.8   virginica
# 110           7.2          3.6           6.1          2.5   virginica
# 111           6.5          3.2           5.1          2.0   virginica
# 112           6.4          2.7           5.3          1.9   virginica
# 113           6.8          3.0           5.5          2.1   virginica
# 115           5.8          2.8           5.1          2.4   virginica
# 116           6.4          3.2           5.3          2.3   virginica
# 117           6.5          3.0           5.5          1.8   virginica
# 118           7.7          3.8           6.7          2.2   virginica
# 119           7.7          2.6           6.9          2.3   virginica
# 121           6.9          3.2           5.7          2.3   virginica
# 123           7.7          2.8           6.7          2.0   virginica
# 125           6.7          3.3           5.7          2.1   virginica
# 126           7.2          3.2           6.0          1.8   virginica
# 129           6.4          2.8           5.6          2.1   virginica
# 130           7.2          3.0           5.8          1.6   virginica
# 131           7.4          2.8           6.1          1.9   virginica
# 132           7.9          3.8           6.4          2.0   virginica
# 133           6.4          2.8           5.6          2.2   virginica
# 134           6.3          2.8           5.1          1.5   virginica
# 135           6.1          2.6           5.6          1.4   virginica
# 136           7.7          3.0           6.1          2.3   virginica
# 137           6.3          3.4           5.6          2.4   virginica
# 138           6.4          3.1           5.5          1.8   virginica
# 140           6.9          3.1           5.4          2.1   virginica
# 141           6.7          3.1           5.6          2.4   virginica
# 142           6.9          3.1           5.1          2.3   virginica
# 143           5.8          2.7           5.1          1.9   virginica
# 144           6.8          3.2           5.9          2.3   virginica
# 145           6.7          3.3           5.7          2.5   virginica
# 146           6.7          3.0           5.2          2.3   virginica
# 148           6.5          3.0           5.2          2.0   virginica
# 149           6.2          3.4           5.4          2.3   virginica
# 150           5.9          3.0           5.1          1.8   virginica
